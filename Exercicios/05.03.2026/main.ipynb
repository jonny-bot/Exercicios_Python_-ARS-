# %%
import pandas as pd

df = pd.read_json('dados/dados2.json')

print(df.head())
# Out:
#   tamanhos     cores  tecidos categorias
# 0        P      azul  algodão   camiseta
# 1        M  vermelho    couro      calça
# 2        P      azul  algodão   camiseta
# 3        G     verde    jeans      calça
# 4        M  vermelho    couro    vestido

# %%
print(df.shape)       # dimensões
print(df.info())      # tipos de dados
print(df.describe())  # estatísticas
# Out:
# (8, 3)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   comprimentos    8 non-null      int64
#  1   palavras_chave  8 non-null      int64
#  2   links_externos  8 non-null      int64
# dtypes: int64(3)
# memory usage: 324.0 bytes
# None
#        comprimentos  palavras_chave  links_externos
# count      8.000000        8.000000        8.000000
# mean     210.000000        0.500000        1.625000
# std       66.975475        0.534522        1.407886
# min      100.000000        0.000000        0.000000
# 25%      172.500000        0.000000        0.750000
# 50%      210.000000        0.500000        1.500000
# 75%      257.500000        1.000000        2.250000
# max      300.000000        1.000000        4.000000
