# %%
import pandas as pd

# %%
df = pd.read_csv('dados/estudos.csv')

# %%
print(df.head())
# Out:
#    ID    Nome  Idade          Cidade          Curso  Nota_Final
# 0   1     Ana     22       São Paulo     Engenharia         8.5
# 1   2   Bruno     25  Rio de Janeiro       Medicina         7.8
# 2   3   Carla     20  Belo Horizonte        Direito         6.9
# 3   4  Daniel     23       São Paulo     Engenharia         9.1
# 4   5   Elisa     21        Curitiba  Administração         7.2

# %%
import matplotlib.pyplot as plt
plt.bar(df['Nome'], df['Nota_Final'])
plt.xlabel('Nome')
plt.ylabel('Nota_Final')
plt.title('Teste')
plt.show()
